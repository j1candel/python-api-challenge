# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Importing Modules 
import os
import csv
import matplotlib as matplot
import json 
import pandas as pd
import numpy as np
import requests
from matplotlib import pyplot as plt
from scipy.stats import linregress
from api_keys import weather_api_key

#Importing City Cordinate Library 
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
#Defining variables as lists 
city_list = []
cordinates = []

#Making a random list of 600 cities 
np.random.seed(14949)

#Picking numbers within the range of latitudes 
lat = np.random.randint(-90, 90, size = 1700)

#Picking numbers within the range of longitudes  
long = np.random.randint(-180, 180, size = 1700)

#Putting the coridnates together 
cordinates = zip(lat, long)

#Finding the name of cities with cordinates 
for cordinates in cordinates: 
    city = citipy.nearest_city(cordinates[0], cordinates[1]).city_name
    
    if city not in city_list:
        city_list.append(city)

#Finding the length of the list of cities 
len(city_list)
# Out:
# 650

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Setting variables equal to a list 
name_list = []
temp_list  = []
hum_list = []
cloud_list = []
wind_speed_list = []
lat_list = []
lon_list = []
country_list = []
date_list = []

#Setting the counter equal to a number 
counter = 1

#Setting the correct url and bulding the query url 
url =  'http://api.openweathermap.org/data/2.5/weather?'

print(f'City List Retrieval')
print('------------------------------')

#Making a for loop to get the elements for each city
for city in city_list:
    try:
        query_url = url + 'appid=' + weather_api_key + '&q=' + city + '&units=imperial'
        weather_response = requests.get(query_url)
        weather_data = weather_response.json()
        
        #Making a list of all the elements needed for the Data Frame 
        name_list.append(weather_data['name'])
        temp_list.append(weather_data['main']['temp_max'])
        hum_list.append(weather_data['main']['humidity'])
        cloud_list.append(weather_data['clouds']['all'])
        wind_speed_list.append(weather_data['wind']['speed'])
        lat_list.append(weather_data['coord']['lat'])
        lon_list.append(weather_data['coord']['lon'])
        country_list.append(weather_data['sys']['country'])
        date_list.append(weather_data['dt'])

        #Print the number of the city and the city name 
        print(f'Processing Record {counter}|{city}')
        
    #Continuing to run even if the city is not found 
    except KeyError:
        
        #Printing the name of the city that does not exist on the open weather api
        print(f'{city} does not exist...Let''s skip it')
    
    #Adding one to the counter 
    counter +=1
# Out:
# City List Retrieval
# ------------------------------
# Processing Record 1|martyush
# Processing Record 2|la ronge
# Processing Record 3|laguna
# Processing Record 4|ajaccio
# Processing Record 5|srednekolymsk
# Processing Record 6|kodiak
# Processing Record 7|saldanha
# Processing Record 8|west bay
# Processing Record 9|albany
# Processing Record 10|georgetown
# Processing Record 11|utevka
# Processing Record 12|punta arenas
# Processing Record 13|berlevag
# Processing Record 14|carnarvon
# Processing Record 15|port alfred
# Processing Record 16|bredasdorp
# Processing Record 17|kapaa
# Processing Record 18|pingxiang
# Processing Record 19|cerinza
# Processing Record 20|gerash
# Processing Record 21|kathmandu
# tumannyy does not exist...Lets skip it
# Processing Record 23|rikitea
# tostamaa does not exist...Lets skip it
# Processing Record 25|bandarbeyla
# belushya guba does not exist...Lets skip it
# Processing Record 27|kysyl-syr
# Processing Record 28|kaitangata
# Processing Record 29|hermanus
# Processing Record 30|codajas
# Processing Record 31|mataura
# Processing Record 32|saskylakh
# Processing Record 33|ushibuka
# illoqqortoormiut does not exist...Lets skip it
# Processing Record 35|atuona
# Processing Record 36|leningradskiy
# Processing Record 37|iskateley
# Processing Record 38|nardaran
# Processing Record 39|nelson bay
# Processing Record 40|alofi
# Processing Record 41|chokurdakh
# Processing Record 42|mehamn
# Processing Record 43|baft
# taolanaro does not exist...Lets skip it
# Processing Record 45|paysandu
# Processing Record 46|sitka
# Processing Record 47|lebu
# Processing Record 48|hokitika
# Processing Record 49|cairns
# Processing Record 50|hobart
# Processing Record 51|raudeberg
# Processing Record 52|pontianak
# Processing Record 53|east london
# Processing Record 54|boyle
# grand centre does not exist...Lets skip it
# Processing Record 56|dikson
# Processing Record 57|dom pedrito
# Processing Record 58|cape town
# Processing Record 59|hilo
# Processing Record 60|husavik
# Processing Record 61|puerto ayora
# Processing Record 62|koscierzyna
# Processing Record 63|leh
# Processing Record 64|gladstone
# Processing Record 65|saint-augustin
# Processing Record 66|mogwase
# Processing Record 67|kovernino
# Processing Record 68|provideniya
# balykshi does not exist...Lets skip it
# tsihombe does not exist...Lets skip it
# Processing Record 71|igarka
# Processing Record 72|christchurch
# Processing Record 73|yellowknife
# Processing Record 74|khatanga
# Processing Record 75|ibicui
# Processing Record 76|florence
# Processing Record 77|mpongwe
# Processing Record 78|ushuaia
# Processing Record 79|mezen
# Processing Record 80|port hardy
# nizhneyansk does not exist...Lets skip it
# Processing Record 82|nome
# Processing Record 83|roma
# Processing Record 84|bluff
# Processing Record 85|luang prabang
# Processing Record 86|avarua
# Processing Record 87|ulaangom
# Processing Record 88|new norfolk
# Processing Record 89|kruisfontein
# Processing Record 90|ilebo
# Processing Record 91|hanover
# Processing Record 92|los llanos de aridane
# tlahualilo does not exist...Lets skip it
# Processing Record 94|iqaluit
# Processing Record 95|stadskanaal
# Processing Record 96|havre-saint-pierre
# scottsburgh does not exist...Lets skip it
# kawana waters does not exist...Lets skip it
# Processing Record 99|tral
# Processing Record 100|barrow
# Processing Record 101|klaksvik
# samusu does not exist...Lets skip it
# Processing Record 103|torres
# Processing Record 104|atasu
# Processing Record 105|mallaig
# Processing Record 106|goianesia
# Processing Record 107|cherskiy
# Processing Record 108|castro
# Processing Record 109|lata
# Processing Record 110|nikolskoye
# Processing Record 111|busselton
# Processing Record 112|faanui
# Processing Record 113|sao filipe
# Processing Record 114|ponta do sol
# Processing Record 115|broken hill
# Processing Record 116|praia
# Processing Record 117|port elizabeth
# Processing Record 118|atar
# vaitupu does not exist...Lets skip it
# Processing Record 120|buala
# Processing Record 121|muros
# banmo does not exist...Lets skip it
# Processing Record 123|fortuna
# Processing Record 124|arraial do cabo
# Processing Record 125|padang
# Processing Record 126|popondetta
# Processing Record 127|san quintin
# Processing Record 128|luderitz
# Processing Record 129|the valley
# Processing Record 130|seligenstadt
# Processing Record 131|barahan
# Processing Record 132|kahului
# Processing Record 133|manokwari
# Processing Record 134|norman wells
# Processing Record 135|bahir dar
# Processing Record 136|inhambane
# Processing Record 137|walvis bay
# Processing Record 138|pevek
# Processing Record 139|bianzhuang
# sentyabrskiy does not exist...Lets skip it
# Processing Record 141|saiki
# Processing Record 142|jalu
# Processing Record 143|bonavista
# Processing Record 144|baie-comeau
# Processing Record 145|mar del plata
# Processing Record 146|tasiilaq
# Processing Record 147|santa isabel
# Processing Record 148|eston
# Processing Record 149|ayagoz
# Processing Record 150|tuktoyaktuk
# Processing Record 151|vila franca do campo
# Processing Record 152|sontra
# Processing Record 153|rochegda
# Processing Record 154|tulagi
# Processing Record 155|gizo
# Processing Record 156|bethel
# Processing Record 157|upernavik
# Processing Record 158|anjozorobe
# Processing Record 159|zhanakorgan
# amderma does not exist...Lets skip it
# Processing Record 161|cabo san lucas
# Processing Record 162|garowe
# Processing Record 163|saint pete beach
# dekoa does not exist...Lets skip it
# Processing Record 165|hasaki
# Processing Record 166|sao joao da barra
# Processing Record 167|lagoa
# Processing Record 168|chitungwiza
# Processing Record 169|portland
# Processing Record 170|vila velha
# Processing Record 171|kodar
# Processing Record 172|vaini
# Processing Record 173|beloha
# Processing Record 174|tizimin
# Processing Record 175|cacequi
# Processing Record 176|cullman
# barentsburg does not exist...Lets skip it
# Processing Record 178|homer
# Processing Record 179|ishigaki
# Processing Record 180|fort nelson
# Processing Record 181|vestmannaeyjar
# Processing Record 182|rorvik
# Processing Record 183|esperance
# Processing Record 184|mweka
# Processing Record 185|ilulissat
# Processing Record 186|mitha tiwana
# Processing Record 187|itarema
# Processing Record 188|nogliki
# Processing Record 189|shenjiamen
# Processing Record 190|sinjai
# Processing Record 191|kurilsk
# Processing Record 192|batagay-alyta
# Processing Record 193|hami
# Processing Record 194|fallon
# Processing Record 195|chuy
# Processing Record 196|aras
# Processing Record 197|coquimbo
# Processing Record 198|el alto
# Processing Record 199|hithadhoo
# Processing Record 200|sorland
# Processing Record 201|butaritari
# Processing Record 202|hwange
# Processing Record 203|souillac
# Processing Record 204|yerbogachen
# Processing Record 205|turukhansk
# Processing Record 206|bathsheba
# mallama does not exist...Lets skip it
# Processing Record 208|banjar
# Processing Record 209|inirida
# Processing Record 210|petropavlovsk-kamchatskiy
# Processing Record 211|saint-philippe
# Processing Record 212|omboue
# Processing Record 213|nouadhibou
# Processing Record 214|sandwick
# Processing Record 215|kavieng
# Processing Record 216|kavaratti
# Processing Record 217|mareeba
# nam tha does not exist...Lets skip it
# Processing Record 219|karratha
# Processing Record 220|lavrentiya
# Processing Record 221|bima
# Processing Record 222|kapit
# ilinsko-podomskoye does not exist...Lets skip it
# Processing Record 224|palmer
# Processing Record 225|qaanaaq
# Processing Record 226|bayanday
# Processing Record 227|yatou
# Processing Record 228|kulhudhuffushi
# Processing Record 229|fergus falls
# Processing Record 230|qandala
# Processing Record 231|iacu
# Processing Record 232|batemans bay
# Processing Record 233|olafsvik
# Processing Record 234|nabire
# Processing Record 235|camacha
# Processing Record 236|pingliang
# Processing Record 237|cozumel
# Processing Record 238|college
# Processing Record 239|saint-joseph
# Processing Record 240|yulara
# Processing Record 241|airai
# Processing Record 242|massena
# Processing Record 243|cidreira
# Processing Record 244|dongsheng
# Processing Record 245|mahebourg
# Processing Record 246|escanaba
# Processing Record 247|virginia beach
# Processing Record 248|ribeira grande
# Processing Record 249|mogadishu
# Processing Record 250|wewak
# Processing Record 251|terra santa
# Processing Record 252|port-gentil
# Processing Record 253|kyzyl-mazhalyk
# Processing Record 254|nemuro
# Processing Record 255|katsuura
# Processing Record 256|valparaiso
# Processing Record 257|allapalli
# Processing Record 258|sorong
# Processing Record 259|bhasawar
# Processing Record 260|salinas
# Processing Record 261|thompson
# Processing Record 262|meulaboh
# Processing Record 263|bubaque
# Processing Record 264|basco
# Processing Record 265|mount isa
# Processing Record 266|caluquembe
# Processing Record 267|shintomi
# Processing Record 268|pisco
# Processing Record 269|jamestown
# Processing Record 270|tiksi
# Processing Record 271|victoria
# Processing Record 272|etla
# Processing Record 273|codrington
# Processing Record 274|purranque
# Processing Record 275|tilichiki
# Processing Record 276|paramonga
# Processing Record 277|tezu
# Processing Record 278|genhe
# Processing Record 279|aykhal
# Processing Record 280|ola
# Processing Record 281|buncrana
# Processing Record 282|kerema
# Processing Record 283|saint anthony
# Processing Record 284|namibe
# Processing Record 285|yinchuan
# Processing Record 286|erzin
# Processing Record 287|ambon
# Processing Record 288|lumut
# Processing Record 289|murray
# Processing Record 290|mingguang
# Processing Record 291|carutapera
# Processing Record 292|umm lajj
# Processing Record 293|poronaysk
# Processing Record 294|wuzhou
# umzimvubu does not exist...Lets skip it
# Processing Record 296|robertsport
# Processing Record 297|oranjemund
# Processing Record 298|derzhavinsk
# Processing Record 299|bara
# Processing Record 300|wuwei
# Processing Record 301|poum
# Processing Record 302|cap-aux-meules
# Processing Record 303|slave lake
# Processing Record 304|imperia
# Processing Record 305|damietta
# cockburn harbour does not exist...Lets skip it
# Processing Record 307|sanchursk
# Processing Record 308|moscow
# Processing Record 309|benguela
# Processing Record 310|grindavik
# Processing Record 311|avera
# Processing Record 312|abha
# Processing Record 313|jabinyanah
# Processing Record 314|kismayo
# Processing Record 315|orshanka
# Processing Record 316|komsomolskiy
# Processing Record 317|kangaatsiaq
# Processing Record 318|ayr
# Processing Record 319|puerto ayacucho
# Processing Record 320|tukrah
# Processing Record 321|bilibino
# Processing Record 322|mayo
# Processing Record 323|medea
# Processing Record 324|real
# Processing Record 325|tigil
# Processing Record 326|east wenatchee
# Processing Record 327|saint george
# Processing Record 328|qui nhon
# Processing Record 329|nuevo ideal
# Processing Record 330|caravelas
# Processing Record 331|ayan
# Processing Record 332|astoria
# Processing Record 333|uhlove
# Processing Record 334|richards bay
# Processing Record 335|bolgar
# Processing Record 336|riverton
# Processing Record 337|carmen
# Processing Record 338|darnah
# Processing Record 339|heerenveen
# Processing Record 340|mao
# armacao dos buzios does not exist...Lets skip it
# Processing Record 342|bereznik
# Processing Record 343|socorro
# Processing Record 344|morehead
# Processing Record 345|juneau
# Processing Record 346|biak
# Processing Record 347|dudinka
# Processing Record 348|burlington
# Processing Record 349|spirit river
# Processing Record 350|nizhniy tagil
# Processing Record 351|jenks
# Processing Record 352|morondava
# Processing Record 353|mountain home
# Processing Record 354|alyangula
# Processing Record 355|sicuani
# Processing Record 356|cam ranh
# Processing Record 357|jesus del monte
# Processing Record 358|nampula
# Processing Record 359|mitsamiouli
# rungata does not exist...Lets skip it
# lolua does not exist...Lets skip it
# Processing Record 362|beringovskiy
# Processing Record 363|touros
# Processing Record 364|serenje
# Processing Record 365|navoi
# Processing Record 366|petropavlovka
# Processing Record 367|bengkulu
# Processing Record 368|langxiang
# Processing Record 369|shaunavon
# Processing Record 370|dawlatabad
# Processing Record 371|addanki
# Processing Record 372|mirnyy
# Processing Record 373|ancud
# Processing Record 374|aklavik
# Processing Record 375|kentau
# saleaula does not exist...Lets skip it
# Processing Record 377|bonthe
# Processing Record 378|kokopo
# Processing Record 379|rawah
# Processing Record 380|elizabeth city
# Processing Record 381|severo-kurilsk
# Processing Record 382|lomza
# Processing Record 383|geraldton
# Processing Record 384|manta
# Processing Record 385|sur
# Processing Record 386|namatanai
# Processing Record 387|korla
# Processing Record 388|sisimiut
# Processing Record 389|canberra
# Processing Record 390|salinopolis
# Processing Record 391|puerto madryn
# Processing Record 392|jega
# Processing Record 393|prince rupert
# Processing Record 394|crestview
# Processing Record 395|clyde river
# palabuhanratu does not exist...Lets skip it
# Processing Record 397|sijunjung
# Processing Record 398|alice springs
# grand river south east does not exist...Lets skip it
# Processing Record 400|yakima
# Processing Record 401|waipawa
# Processing Record 402|edd
# Processing Record 403|buraydah
# Processing Record 404|hit
# Processing Record 405|champerico
# Processing Record 406|bay-ang
# Processing Record 407|narsaq
# Processing Record 408|marsh harbour
# Processing Record 409|samarai
# Processing Record 410|broome
# hihifo does not exist...Lets skip it
# mys shmidta does not exist...Lets skip it
# Processing Record 413|boa vista
# Processing Record 414|udachnyy
# Processing Record 415|avrameni
# Processing Record 416|guerrero negro
# Processing Record 417|henties bay
# Processing Record 418|oga
# Processing Record 419|vanavara
# Processing Record 420|manicore
# Processing Record 421|kieta
# Processing Record 422|port lincoln
# Processing Record 423|guadalupe y calvo
# Processing Record 424|santa cruz
# Processing Record 425|nhulunbuy
# Processing Record 426|dalbandin
# Processing Record 427|yumen
# Processing Record 428|torbay
# Processing Record 429|paamiut
# Processing Record 430|westport
# Processing Record 431|zhaotong
# Processing Record 432|constitucion
# Processing Record 433|siocon
# marcona does not exist...Lets skip it
# Processing Record 435|axim
# Processing Record 436|ujhani
# Processing Record 437|el guamo
# Processing Record 438|oktyabrskiy
# Processing Record 439|george
# Processing Record 440|yerofey pavlovich
# Processing Record 441|hobyo
# Processing Record 442|acarau
# Processing Record 443|enshi
# Processing Record 444|buchanan
# Processing Record 445|harer
# Processing Record 446|esmeraldas
# Processing Record 447|longyearbyen
# Processing Record 448|arroyo
# Processing Record 449|ploemeur
# Processing Record 450|dong hoi
# Processing Record 451|zhengjiatun
# Processing Record 452|san lawrenz
# Processing Record 453|tarakan
# Processing Record 454|zvishavane
# Processing Record 455|nykoping
# Processing Record 456|tombouctou
# Processing Record 457|tuatapere
# Processing Record 458|lima duarte
# Processing Record 459|labuhan
# Processing Record 460|dongying
# Processing Record 461|las palmas
# Processing Record 462|kattivakkam
# Processing Record 463|zemio
# Processing Record 464|erenhot
# angra does not exist...Lets skip it
# Processing Record 466|andenes
# Processing Record 467|kui buri
# Processing Record 468|weihai
# Processing Record 469|orlik
# Processing Record 470|ontario
# Processing Record 471|bonito
# Processing Record 472|balkhash
# Processing Record 473|alugan
# Processing Record 474|ystad
# Processing Record 475|young
# Processing Record 476|birao
# Processing Record 477|santa fe
# hvammstangi does not exist...Lets skip it
# kamenskoye does not exist...Lets skip it
# Processing Record 480|veraval
# haibowan does not exist...Lets skip it
# Processing Record 482|ntcheu
# Processing Record 483|galle
# Processing Record 484|cabedelo
# nguiu does not exist...Lets skip it
# Processing Record 486|shepetivka
# Processing Record 487|antofagasta
# Processing Record 488|maningrida
# Processing Record 489|calceta
# Processing Record 490|hirara
# tidore does not exist...Lets skip it
# Processing Record 492|ouro fino
# Processing Record 493|alta floresta
# Processing Record 494|lompoc
# Processing Record 495|giyani
# Processing Record 496|kutum
# Processing Record 497|ostrovnoy
# Processing Record 498|sioux lookout
# Processing Record 499|egvekinot
# Processing Record 500|deer lake
# Processing Record 501|zambezi
# Processing Record 502|santa rosa del sur
# Processing Record 503|alpena
# Processing Record 504|bombay
# Processing Record 505|necochea
# Processing Record 506|northam
# Processing Record 507|bucerias
# Processing Record 508|arman
# Processing Record 509|topchikha
# Processing Record 510|moerai
# Processing Record 511|vrangel
# Processing Record 512|la palma
# Processing Record 513|nizwa
# Processing Record 514|bilma
# Processing Record 515|salalah
# Processing Record 516|naze
# Processing Record 517|gimli
# Processing Record 518|pascagoula
# Processing Record 519|monster
# toliary does not exist...Lets skip it
# Processing Record 521|barhi
# Processing Record 522|bambous virieux
# Processing Record 523|kimbe
# Processing Record 524|mount gambier
# Processing Record 525|sept-iles
# Processing Record 526|khirkiya
# Processing Record 527|nishihara
# Processing Record 528|morant bay
# Processing Record 529|umm kaddadah
# Processing Record 530|williamsport
# Processing Record 531|yar-sale
# Processing Record 532|ixtapa
# bur gabo does not exist...Lets skip it
# Processing Record 534|cravo norte
# Processing Record 535|quatre cocos
# geresk does not exist...Lets skip it
# Processing Record 537|mirandola
# Processing Record 538|machico
# attawapiskat does not exist...Lets skip it
# Processing Record 540|nanortalik
# Processing Record 541|yaan
# Processing Record 542|bukama
# Processing Record 543|lyngseidet
# Processing Record 544|pudozh
# Processing Record 545|beyneu
# Processing Record 546|santa catarina de tepehuanes
# Processing Record 547|carahue
# Processing Record 548|hamilton
# ust-kamchatsk does not exist...Lets skip it
# Processing Record 550|mahibadhoo
# Processing Record 551|lorengau
# Processing Record 552|tanete
# warqla does not exist...Lets skip it
# Processing Record 554|roebourne
# Processing Record 555|vao
# Processing Record 556|oistins
# bolungarvik does not exist...Lets skip it
# Processing Record 558|znamenskoye
# Processing Record 559|coahuayana
# Processing Record 560|tairua
# Processing Record 561|rock springs
# Processing Record 562|lakatoro
# Processing Record 563|san juan
# Processing Record 564|filadelfia
# Processing Record 565|heihe
# halalo does not exist...Lets skip it
# Processing Record 567|hay river
# Processing Record 568|taoudenni
# Processing Record 569|altus
# mentok does not exist...Lets skip it
# Processing Record 571|liverpool
# Processing Record 572|morropon
# Processing Record 573|mozarlandia
# Processing Record 574|sao paulo de olivenca
# Processing Record 575|great bend
# Processing Record 576|diamantino
# Processing Record 577|adrar
# Processing Record 578|abu samrah
# Processing Record 579|oum hadjer
# Processing Record 580|linhares
# Processing Record 581|shelburne
# Processing Record 582|guarapari
# Processing Record 583|porbandar
# Processing Record 584|huarmey
# Processing Record 585|badarganj
# Processing Record 586|rafaela
# Processing Record 587|melita
# Processing Record 588|sydney
# Processing Record 589|licata
# Processing Record 590|vikyrovice
# Processing Record 591|ciudad real
# Processing Record 592|ayorou
# Processing Record 593|wad rawah
# Processing Record 594|quelimane
# Processing Record 595|santa maria
# Processing Record 596|batticaloa
# Processing Record 597|saint-raymond
# Processing Record 598|floro
# Processing Record 599|makakilo city
# Processing Record 600|storebo
# Processing Record 601|ahipara
# Processing Record 602|bahia honda
# Processing Record 603|lokoja
# Processing Record 604|singanallur
# Processing Record 605|fredericton
# Processing Record 606|rodrigues alves
# Processing Record 607|chumikan
# Processing Record 608|arrecife
# Processing Record 609|fairbanks
# Processing Record 610|grand-lahou
# Processing Record 611|harmanli
# Processing Record 612|chalmette
# Processing Record 613|bardiyah
# Processing Record 614|pontal do parana
# Processing Record 615|vagur
# Processing Record 616|kumukh
# Processing Record 617|cayenne
# Processing Record 618|seymchan
# Processing Record 619|malindi
# Processing Record 620|steamboat springs
# Processing Record 621|griffith
# mendahara does not exist...Lets skip it
# Processing Record 623|rudbar
# Processing Record 624|dingle
# Processing Record 625|east brainerd
# Processing Record 626|amasya
# Processing Record 627|cintalapa
# Processing Record 628|takoradi
# Processing Record 629|flinders
# Processing Record 630|zhangye
# Processing Record 631|krasnokholmskiy
# Processing Record 632|rassvet
# Processing Record 633|minsk
# Processing Record 634|sao felix do xingu
# tabiauea does not exist...Lets skip it
# jinchengjiang does not exist...Lets skip it
# Processing Record 637|vardo
# Processing Record 638|shingu
# Processing Record 639|cascais
# Processing Record 640|soyo
# sinkat does not exist...Lets skip it
# Processing Record 642|sola
# Processing Record 643|dano
# Processing Record 644|rostovka
# Processing Record 645|sokoni
# Processing Record 646|corinto
# sulurpeta does not exist...Lets skip it
# Processing Record 648|betlitsa
# Processing Record 649|seoul
# Processing Record 650|chicama

# %%
#Making the city data into a dictionary
city_data = {'City':name_list,
        'Temperature °F':temp_list,
        'Humidity':hum_list,
        'Cloudiness':cloud_list,
        'Wind Speed':wind_speed_list,
        'Latitude':lat_list,
        'Longitude':lon_list,
        'Country':country_list,
        'Date':date_list
            }

#Converting into a data frame 
city_data_pd = pd.DataFrame(city_data)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Displaing the data frame 
city_data_pd
# Out:
#                          City  Temperature °F  Humidity  Cloudiness  \
# 0                    Martyush           49.60        92         100
# 1                    La Ronge           51.80        71          20
# 2                      Laguna           77.00        40           1
# 3    Arrondissement d'Ajaccio           53.60        87          20
# 4               Srednekolymsk           52.99        53         100
# ..                        ...             ...       ...         ...
# 592                    Sokoni           77.86        76         100
# 593                   Corinth           66.99        60           1
# 594                  Betlitsa           50.36        91          97
# 595                     Seoul           77.00        43          20
# 596                   Chicama           61.07        82          20
#
#      Wind Speed  Latitude  Longitude Country        Date
# 0          4.16     56.40      61.88      RU  1601354370
# 1         10.29     55.10    -105.28      CA  1601354134
# 2          4.61     38.42    -121.42      US  1601354093
# 3          8.05     42.00       8.92      FR  1601354371
# 4         10.27     67.45     153.68      RU  1601354147
# ..          ...       ...        ...     ...         ...
# 592        8.81     -6.43      39.55      TZ  1601354549
# 593        1.99     37.94      22.96      GR  1601354549
# 594        5.86     54.01      33.96      RU  1601354550
# 595        8.14     37.57     126.98      KR  1601354550
# 596        4.85     -7.84     -79.15      PE  1601354550
#
# [597 rows x 9 columns]

# %%
city_data_pd.to_csv('city_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No data where the humidity > 100%
city_data_pd.loc[city_data_pd['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Temperature °F, Humidity, Cloudiness, Wind Speed, Latitude, Longitude, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Setting the x and y values 
x_values = city_data_pd['Latitude']
y_values = city_data_pd['Temperature °F']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (40,80), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Temperature °F')
plt.title('Latitude v Temperature °F')
plt.savefig('Latitude v Temperature °F.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Setting the x and y values 
x_values = city_data_pd['Latitude']
y_values = city_data_pd['Humidity']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (4,7), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('Latitude v Humidity(%)')
plt.savefig('Latitude v Humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Setting the x and y values 
x_values = city_data_pd['Latitude']
y_values = city_data_pd['Cloudiness']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (16,42), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Clouiness(%)')
plt.title('Latitude v Cloudiness(%)')
plt.savefig('Latitude v Cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Setting the x and y values 
x_values = city_data_pd['Latitude']
y_values = city_data_pd['Wind Speed']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-60,9), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('Latitude v Wind Speed(mph)')
plt.savefig('Latitude v Wind Speed.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Filtering only the northern hemisphere data 
north_hem_pd = city_data_pd.loc[city_data_pd['Latitude']>=0]

#Setting the x and y values 
x_values = north_hem_pd['Latitude']
y_values = north_hem_pd['Temperature °F']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (0,50), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Temperature °F')
plt.title('Northern Hemisphere Latitude v Temperature °F')
plt.savefig('Latitude v Temperature °F (N).png')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Filtering only the southern hemisphere data 
south_hem_pd = city_data_pd.loc[city_data_pd['Latitude']<0]

#Setting the x and y values 
x_values = south_hem_pd['Latitude']
y_values = south_hem_pd['Temperature °F']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-57,53), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Temperature °F')
plt.title('Southern Hemisphere Latitude v Temperature °F')
plt.savefig('Latitude v Temperature °F (S).png')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = north_hem_pd['Latitude']
y_values = north_hem_pd['Humidity']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (0,45), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('Northern Hemisphere Latitude v Humidity(%)')
plt.savefig('Latitude v Humidity(%)(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = south_hem_pd['Latitude']
y_values = south_hem_pd['Humidity']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-55,62), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('Southern Hemisphere Latitude v Humidity(%)')
plt.savefig('Latitude v Humidity(%)(S).png')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = north_hem_pd['Latitude']
y_values = north_hem_pd['Cloudiness']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (0,30), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Northern Hemisphere Latitude v Cloudiness(%)')
plt.savefig('Latitude v Cloudiness(%)(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = south_hem_pd['Latitude']
y_values = south_hem_pd['Cloudiness']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-55,0), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Southern Hemisphere Latitude v Cloudiness(%)')
plt.savefig('Latitude v Cloudiness(%)(S).png')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = north_hem_pd['Latitude']
y_values = north_hem_pd['Wind Speed']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (0,16), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('Northern Hemisphere Latitude v Wind Speed(mph)')
plt.savefig('Latitude v Wind Speed(mph)(N).png')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Setting the x and y values 
x_values = south_hem_pd['Latitude']
y_values = south_hem_pd['Wind Speed']

#Solving for the linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept 
line_eq = 'y =' + str(round(slope,2)) +'x +' + str(round(intercept,2))

#Plotting the scatter plot 
plt.scatter(x_values, y_values)

#Plotting the linear regression line 
plt.plot(x_values, regress_values, 'r-')
plt.annotate(line_eq, (-55,5), fontsize = 11, color = 'red')

#Setting the labels 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere Latitude v Wind Speed (mph)')
plt.savefig('Latitude v Wind Speed(mph)(S).png')
